# %%
import cv2
import os
import glob
from PIL import Image
import numpy as np
import pandas as pd

# %%
file_list = glob.glob('food/food-101_256/**/*.jpg', recursive=True)

# %%
dir_list = glob.glob('food/food-101_256/**/', recursive=True)

# %%
dir_list = dir_list[2:]

# %%
dir_list_image = dir_list[:101]
dir_list_meta = dir_list[102:]

# %%
dir_list_image[-1]
# Out:
# 'food/food-101_256/images/spaghetti_bolognese/'

# %%
s = dir_list[0] +'*.jpg'

# %%
file_num = 0
for s in dir_list_image:
    ss = s + '*.jpg'
    f = glob.glob(ss, recursive=True)
    print(len(f))
    file_num += len(f)
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000

# %%
file_num
# Out:
# 101000

# %%
dir_list_meta
# Out:
# ['food/food-101_256/meta/beignets/',
#  'food/food-101_256/meta/prime_rib/',
#  'food/food-101_256/meta/ramen/',
#  'food/food-101_256/meta/hamburger/',
#  'food/food-101_256/meta/bruschetta/',
#  'food/food-101_256/meta/chicken_wings/',
#  'food/food-101_256/meta/pork_chop/',
#  'food/food-101_256/meta/greek_salad/',
#  'food/food-101_256/meta/sashimi/',
#  'food/food-101_256/meta/risotto/',
#  'food/food-101_256/meta/pizza/',
#  'food/food-101_256/meta/eggs_benedict/',
#  'food/food-101_256/meta/guacamole/',
#  'food/food-101_256/meta/chocolate_cake/',
#  'food/food-101_256/meta/miso_soup/',
#  'food/food-101_256/meta/apple_pie/',
#  'food/food-101_256/meta/fried_calamari/',
#  'food/food-101_256/meta/fried_rice/',
#  'food/food-101_256/meta/panna_cotta/',
#  'food/food-101_256/meta/hummus/',
#  'food/food-101_256/meta/carrot_cake/',
#  'food/food-101_256/meta/beet_salad/',
#  'food/food-101_256/meta/garlic_bread/',
#  'food/food-101_256/meta/hot_dog/',
# ...

# %%
header_images = 'food/food-101_256/images/'
header_train = 'food/food-101_256/train/'
header_test = 'food/food-101_256/test/'

# %%
train_list = pd.read_csv('./food/food-101_256/meta/train.txt', header=None)
test_list = pd.read_csv('./food/food-101_256/meta/test.txt', header=None)

# %%
for d in train_list.loc[:,0]:
    path_from = so.path.join(header_images, d)
    path_to = so.path.join(header_images, d)
    
        
    
    print(i)
# Out:
# apple_pie/1005649
# apple_pie/1014775
# apple_pie/1026328
# apple_pie/1028787
# apple_pie/1043283
# apple_pie/1050519
# apple_pie/1057749
# apple_pie/1057810
# apple_pie/1072416
# apple_pie/1074856
# apple_pie/1074942
# apple_pie/1076891
# apple_pie/1077610
# apple_pie/1077964
# apple_pie/1088809
# apple_pie/1097378
# apple_pie/1103795
# apple_pie/1109597
# apple_pie/1111062
# apple_pie/1112300
# apple_pie/1112838
# apple_pie/1121884
# apple_pie/112378
# apple_pie/1133267
# apple_pie/1142597
# apple_pie/1147371
# apple_pie/1154371
# apple_pie/1158360
# apple_pie/1159801
# apple_pie/1165004
# apple_pie/1166116
# apple_pie/1166210
# apple_pie/116697
# apple_pie/1174241
# apple_pie/1174949
# apple_pie/1177254
# apple_pie/118237
# apple_pie/1184568
# apple_pie/1185445
# apple_pie/1185654
# apple_pie/1191665
# apple_pie/1196628
# apple_pie/1199851
# apple_pie/1200079
# apple_pie/1214326
# apple_pie/1215650
# apple_pie/1218767
# apple_pie/1220194
# apple_pie/1230465
# apple_pie/1232311
# ...

# %%
file_list_arr = np.array(file_list)

# %%
np.save('file_list',file_list_arr)

# %%
a = np.load('file_list.npy')

# %%
enu
# Out:
# 101000

# %%
img = Image.open(file_list[0])

# %%
img_resize = img.resize((256, 256))
# img_resize.save(ftitle + '_half' + fext)

# %%
img_resize.save(file_list[0].replace('food-101', 'food-101_256'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-83c536671187> in <module>()
# ----> 1 img_resize.save(file_list[0].replace('food-101', 'food-101_256'))
#
# /usr/local/lib/python3.5/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    1945                 # Open also for reading ("+"), because TIFF save_all
#    1946                 # writer needs to go back and edit the written data.
# -> 1947                 fp = builtins.open(filename, "w+b")
#    1948
#    1949         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'food/food-101_256/images/beignets/2885220.jpg'

# %%
dir_list = glob.glob('food/**/', recursive=True)

# %%
dir_list = dir_list[2:]

# %%
dir_list_images = [d.replace('food-101', 'food-101_256') for d in dir_list]

# %%
for d in dir_list_images:
    os.makedirs(d)

# %%
dir_list_meta = [d.replace('images', 'meta') for d in dir_list_images]

# %%
for d in dir_list_meta:
    if os.path.isdir(d) is not True:
        os.makedirs(d)

# %%
os.path.isdir('food/food-101_256/meta/') is not True
# Out:
# False

# %%
len(file_list)
# Out:
# 101000

# %%
np.save(file_list, 'file_list')
# Out:
# ['food/food-101/images/beignets/2885220.jpg',
#  'food/food-101/images/beignets/1814040.jpg',
#  'food/food-101/images/beignets/81202.jpg',
#  'food/food-101/images/beignets/1827892.jpg',
#  'food/food-101/images/beignets/2802124.jpg',
#  'food/food-101/images/beignets/2192983.jpg',
#  'food/food-101/images/beignets/250043.jpg',
#  'food/food-101/images/beignets/2786548.jpg',
#  'food/food-101/images/beignets/445116.jpg',
#  'food/food-101/images/beignets/3661460.jpg',
#  'food/food-101/images/beignets/1064858.jpg',
#  'food/food-101/images/beignets/2993714.jpg',
#  'food/food-101/images/beignets/2936669.jpg',
#  'food/food-101/images/beignets/1062952.jpg',
#  'food/food-101/images/beignets/2869806.jpg',
#  'food/food-101/images/beignets/178659.jpg',
#  'food/food-101/images/beignets/1261083.jpg',
#  'food/food-101/images/beignets/1296128.jpg',
#  'food/food-101/images/beignets/3157161.jpg',
#  'food/food-101/images/beignets/646871.jpg',
# ...
